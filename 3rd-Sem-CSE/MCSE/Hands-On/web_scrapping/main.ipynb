# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
website = "https://ackodrive.com/cars/"

# %%
response = requests.get(website)
response.status_code
# Out:
# 200

# %%
soup = bs(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    New Cars in India 2025 - Buy Cars Online - Home Delivery
#   </title>
#   <meta content="New Cars in India 2025 - Buy Cars Online - Home Delivery" name="title"/>
#   <meta content="Buy Cars online in India. Shop for New Cars and get Doorstep delivery ✓ Guaranteed Lowest Price on New Car Purchase ✓ Amazing Offers." name="description"/>
#   <meta content="en_US" name="og:locale"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://ackodrive.com/cars/" rel="canonical"/>
#   <meta content="https://ackodrive.com/" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="ACKO Drive" property="og:site_name"/>
#   <meta content="New Cars in India 2025 - Buy Cars Online - Home Delivery" property="og:title"/>
# ...

# %%
results = soup.find_all('div', {'data-testid':'listingcardesktop'})
print(results)
len(results)
# Out:
# [<div class="styles__Wrapper-sc-ad1b3a08-0 iTGjuL" data-testid="listingcardesktop"><div class="styles__ModelSection-sc-ad1b3a08-1 cZBYsU"><div class="styles__ModelDetails-sc-a6403e05-0 edzyap"><div class="styles__BestsellerWrapper-sc-a6403e05-7 htBjOW" data-testid="best_seller"><svg class="styles__StyledBestSellerStarIcon-sc-ad1b3a08-7 bnpuUg" fill="none" height="13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M5.53 4.165 7 1.186l1.47 2.98c.15.302.438.511.772.56l3.287.477-2.379 2.32a1.025 1.025 0 0 0-.294.906l.561 3.274-2.94-1.545a1.025 1.025 0 0 0-.954 0l-2.94 1.545.561-3.274a1.025 1.025 0 0 0-.294-.907L1.47 5.203l3.288-.477c.334-.049.623-.258.772-.56Z" stroke="#fff" stroke-width="1.05"></path></svg>Bestseller</div><a class="styles__AnchorTagWithoutUnderline-sc-a6403e05-33 bXIogR" data-testid="car_model_brand_title" href="https://ackodrive.com/cars/hyundai-creta/"><div class="styles__ModelStatusWrapper-sc-4db1e074-14 brdlRa"><h2 class="styles__ModelTitle-sc-a6403e05-4 ARH
# ...

# %%
first = results[0]
print(first)
# Out:
# <div class="styles__Wrapper-sc-ad1b3a08-0 iTGjuL" data-testid="listingcardesktop"><div class="styles__ModelSection-sc-ad1b3a08-1 cZBYsU"><div class="styles__ModelDetails-sc-a6403e05-0 edzyap"><div class="styles__BestsellerWrapper-sc-a6403e05-7 htBjOW" data-testid="best_seller"><svg class="styles__StyledBestSellerStarIcon-sc-ad1b3a08-7 bnpuUg" fill="none" height="13" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M5.53 4.165 7 1.186l1.47 2.98c.15.302.438.511.772.56l3.287.477-2.379 2.32a1.025 1.025 0 0 0-.294.906l.561 3.274-2.94-1.545a1.025 1.025 0 0 0-.954 0l-2.94 1.545.561-3.274a1.025 1.025 0 0 0-.294-.907L1.47 5.203l3.288-.477c.334-.049.623-.258.772-.56Z" stroke="#fff" stroke-width="1.05"></path></svg>Bestseller</div><a class="styles__AnchorTagWithoutUnderline-sc-a6403e05-33 bXIogR" data-testid="car_model_brand_title" href="https://ackodrive.com/cars/hyundai-creta/"><div class="styles__ModelStatusWrapper-sc-4db1e074-14 brdlRa"><h2 class="styles__ModelTitle-sc-a6403e05-4 ARHd
# ...

# %%
first.find('h2').get_text()
# Out:
# 'Hyundai Creta'

# %%
car_names = [cars.find('h2').get_text() for cars in results]

# for i in range(0, len(results)):
#     car_names.append(results[i].find('h2').get_text())
    
#Better Implementation:
# for cars in results:
#     car_names.append(cars.find('h2').get_text())

car_names
# Out:
# ['Hyundai Creta',
#  'Hyundai Venue',
#  'Kia Sonet',
#  'Kia Syros',
#  'Maruti Suzuki Baleno (2022-2025)',
#  'Maruti Suzuki Brezza',
#  'Maruti Suzuki Grand Vitara',
#  'Mahindra XUV700',
#  'Mahindra Scorpio-N',
#  'Tata Punch',
#  'Tata Nexon',
#  'Tata Curvv EV',
#  'Maruti Suzuki Swift',
#  'Hyundai Grand i10 Nios',
#  'Hyundai Aura',
#  'Maruti Suzuki Wagon R']

# %%
car_names.pop(3)
car_names.pop(0)
car_names.pop(4)
car_names.pop(5)
# Out:
# 'Maruti Suzuki Swift'

# %%
first.find('div', {'data-testid':'car_price'}).get_text()
# Out:
# '₹12.98 L'

# %%
first.find('p', {'data-testid':'car_variant_transmission'}).get_text()
# Out:
# 'Manual'

# %%
first.find('p', {'data-testid':'car_variant_fuel_type'}).get_text()
# Out:
# 'Petrol'

# %%
first.find_all('p')
# Out:
# [<p class="styles__ParaWithoutMargins-sc-a6403e05-34 iAPjDz" data-testid="car_model_body_type">SUV</p>,
#  <p class="styles__ParaWithoutMargins-sc-a6403e05-34 iAPjDz" data-testid="car_model_seat">5 Seater</p>,
#  <p class="styles__ParaWithoutMargins-sc-a6403e05-34 iAPjDz" data-testid="car_model_variants">1/34 variants</p>,
#  <p class="styles__ParaWithoutMargins-sc-a6403e05-34 iAPjDz" data-testid="car_variant_fuel_type">Petrol</p>,
#  <p class="styles__ParaWithoutMargins-sc-a6403e05-34 iAPjDz" data-testid="car_variant_transmission">Manual</p>,
#  <p class="styles__ParaWithoutMargins-sc-a6403e05-34 iAPjDz">Available in 11 colors</p>]

# %%
first.find_all('p')[5].get_text().lstrip(('Available in ')).rstrip(' colors')
# Out:
# '11'

# %%
cars = []
for i in range(0, len(results)):
    car = results[i]
    name = car.find('h2').get_text()
    price = car.find('div', {'data-testid':'car_price'}).get_text()
    fuel_type = car.find('p', {'data-testid':'car_variant_fuel_type'}).get_text()
    colors = car.find_all('p')[5].get_text().lstrip(('Available in '))
    
    cars.append({
        "Name": name,
        "Price":price,
        "Fuel Type": fuel_type,
        "Colors":colors,
    })
    
df = pd.DataFrame(cars)
df
# Out:
#                                 Name     Price Fuel Type     Colors
# 0                      Hyundai Creta  ₹12.98 L    Petrol  11 colors
# 1                      Hyundai Venue   ₹9.03 L    Petrol   4 colors
# 2                          Kia Sonet   ₹9.47 L    Petrol   7 colors
# 3                          Kia Syros  ₹10.57 L    Petrol   8 colors
# 4   Maruti Suzuki Baleno (2022-2025)   ₹7.55 L    Petrol   6 colors
# 5               Maruti Suzuki Brezza   ₹9.73 L    Petrol   5 colors
# 6         Maruti Suzuki Grand Vitara  ₹13.10 L    Petrol    1 color
# 7                    Mahindra XUV700  ₹17.74 L    Petrol   5 colors
# 8                 Mahindra Scorpio-N  ₹16.86 L    Petrol   3 colors
# 9                         Tata Punch   ₹6.68 L    Petrol   2 colors
# 10                        Tata Nexon   ₹9.99 L    Petrol   4 colors
# 11                     Tata Curvv EV  ₹20.29 L  Electric   4 colors
# 12               Maruti Suzuki Swift   ₹7.28 L    Petrol   4 colors
# ...

# %%
df.to_csv("./output.csv")
