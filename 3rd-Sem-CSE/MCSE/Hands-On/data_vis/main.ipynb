# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
height = [120, 80, 60, 150, 170]
labels = ['Math', 'Physics', 'Chemistry', 'Computer Science', 'Geology']

plt.bar(x, height, align='center', color='skyblue', edgecolor='black')
plt.xticks(x, labels)

# Set y-axis ticks for student counts
plt.yticks([0, 50, 100, 150, 200])

plt.title("Number of Students Enrolled in Courses")
plt.ylabel("Student Count")
plt.show()

# %%
x = [1, 2, 3, 4]
height = [120, 80, 60, 150]
labels = ['Math', 'Physics', 'Chemistry', 'Computer Science']

plt.barh(x, height, align='center', color='lightgreen', edgecolor='black')  # Horizontal bars

# Set y-axis labels at positions x
plt.yticks(x, labels)

# Set x-axis (count of students)
plt.xticks([0, 50, 100, 150, 200])

plt.title("Number of Students Enrolled in Courses")
plt.xlabel("Student Count")  # X-axis is horizontal (count axis now)
plt.ylabel("Course Name")    # Optional: for clarity

plt.show()

# %%
#edge aligned bar charts
plt.bar(x, height, align='edge',ec='red',color='green')
plt.xticks(x, labels)
plt.title("Edge-Aligned Bar Chart")
plt.show()

# %%
# X-axis positions
x = [1, 2, 3, 4]

# Data: Units sold through each channel
online = [120, 150, 90, 130]
offline = [80, 100, 60, 70]

# Labels for each product
labels = ['Shoes', 'Bags', 'Shirts', 'Jeans']

# Create stacked bars
p1 = plt.bar(x, online, color='skyblue')
p2 = plt.bar(x, offline, bottom=online, color='orange')

# Custom x-axis labels
plt.xticks(x, labels)

# Add legend
plt.legend((p1[0], p2[0]), ('Online Sales', 'Offline Sales'))

# Add titles and labels
plt.title("Product Sales: Online vs Offline")
plt.ylabel("Units Sold")

# Display the chart
plt.show()

# %%
# X positions
x = np.arange(5)  # 0,1,2,3,4

# Scores in 5 subjects
class_A = [85, 78, 92, 74, 88]
class_B = [80, 83, 89, 70, 90]

# Subject labels
subjects = ['Math', 'Science', 'English', 'History', 'Art']

# Width of each bar
width = 0.4

# Grouped bars
p1 = plt.bar(x - width/2, class_A, width, color='lightgreen')
p2 = plt.bar(x + width/2, class_B, width, color='yellow')

# X-axis labels and positions
plt.xticks(x, subjects)

# Legend
plt.legend((p1[0], p2[0]), ('Class A', 'Class B'))

# Axis labels and title
plt.ylabel('Scores')
plt.title('Subject-wise Test Scores: Class A vs Class B')

# Show plot
plt.show()

# %%
# X-axis positions
x = np.arange(5)  # x = [0,1,2,3,4]

# Revenue (in $1000s) for 3 products across 5 months
product_A = [50, 70, 65, 80, 90]
product_B = [60, 55, 75, 70, 85]
product_C = [40, 65, 60, 72, 88]

# Width of each bar
width = 0.2

# Grouped bars
plt.bar(x - 0.2, product_A, width, color='skyblue')
plt.bar(x, product_B, width, color='lightcoral')
plt.bar(x + 0.2, product_C, width, color='lightgreen')

# X-axis labels
plt.xticks(x, ['Jan', 'Feb', 'Mar', 'Apr', 'May'])

# Axis labels and title
plt.xlabel("Month")
plt.ylabel("Revenue ($1000s)")
plt.title("Monthly Revenue Comparison Across Products")

# Legend
plt.legend(["Product A", "Product B", "Product C"])

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df=pd.read_csv('Dataset_sampling.csv')
df.head(5)
# Out:
#   Student_ID Department  Gender   Age    GPA  Credits_Completed  Attendance  \
# 0      S1152        CSE  Female  20.0  10.00              140.0       65.54
# 1      S1260        ECE    Male  18.0  10.00              140.0       73.51
# 2      S1253         ME    Male  23.0  10.00              140.0       66.95
# 3      S1004        EEE    Male  21.0  10.00              140.0       80.00
# 4      S1345        ECE    Male  23.0   9.96              140.0        5.00
#
#   Scholarship
# 0          No
# 1         Yes
# 2          No
# 3          No
# 4          No

# %%
sns.countplot(x='Department', data=df)
plt.title("Count of Each Department")
plt.xlabel("Department")
plt.ylabel("Count")
plt.show()

# %%
# Sample DataFrame
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})

# Box plot of ratings
plt.boxplot(df['rating'])
plt.title('Box Plot of Ratings')
plt.ylabel('Rating')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import boxplot, show  #libraries req for boxplot

# Daily temperatures in °C for 20 days
temperatures = [22, 24, 19, 21, 18, 25, 30, 28, 27, 23, 26, 29, 24, 22, 20, 31, 33, 28, 26, 25, 45, 5]  #datapoints need not be ordered

plt.boxplot(temperatures, vert=True, showfliers=True)   #simple way to create a boxplot

plt.title("Box Plot of Daily Temperatures (°C)")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
plt.boxplot(temperatures, vert=False, showfliers=False)   #to remove all the outliers and horizontal plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Daily temperatures with outliers
temperatures = [22, 24, 19, 21, 18, 25, 30, 28, 27, 23, 26, 29, 24, 22, 20, 31, 33, 28, 26, 25, 45, 5]

plt.boxplot(temperatures, vert=True, whis=1.5, showfliers=True) #default whisker value
plt.show()

plt.boxplot(temperatures, vert=True, whis=2.0, showfliers=True) # whisker = 2 fewer outlier
plt.show()

# Boxplot with whiskers covering full data range
range=[min(temperatures),max(temperatures)]
plt.boxplot(temperatures, vert=True, whis=range, showfliers=True)

plt.title("Box Plot of Daily Temperatures (°C)")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
plt.boxplot(temperatures, meanline=True, showmeans=True, vert=True)   #to show the mean of the datapoints
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Random test scores for 3 schools (mean, std, number of students)
school_1 = np.random.normal(75, 5, 100)   # School A: high-performing
school_2 = np.random.normal(65, 10, 100)  # School B: average
school_3 = np.random.normal(55, 15, 100)  # School C: low average, more spread

# Combine into a list
scores = [school_1, school_2, school_3]

# Boxplot
plt.boxplot(scores, showmeans=True, meanline=True)

# X-axis labels
plt.xticks([1, 2, 3], ['School A', 'School B', 'School C'])

# Titles and labels
plt.title("Box Plot of Test Scores by School")
plt.ylabel("Test Scores")


# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import statistics as st
df = pd.read_csv("./data_vis/Dataset_Boxplot_Train.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df = pd.read_csv("./data_vis/Dataset_Boxplot_Train.csv")
 # Calculate IQR and detect outliers
Q1 = df['ApplicantIncome'].quantile(0.25)
Q3 = df['ApplicantIncome'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound)
print(upper_bound)
outliers = df[(df['ApplicantIncome'] < lower_bound) | (df['ApplicantIncome'] > upper_bound)]

print("Outliers in 'ApplicantIncome' column:")
print(outliers)

#  Box plot
plt.boxplot(df['ApplicantIncome'], vert=True, whis=1.5, showfliers=True)
plt.title("Box Plot of ApplicantIncome")
plt.ylabel("ApplicantIncome")
plt.show()
# Out:
# -1498.75
# 10171.25
# Outliers in 'ApplicantIncome' column:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 67   LP001233    Male     Yes          1      Graduate            No
# 102  LP001350    Male     Yes        NaN      Graduate            No
# 106  LP001369    Male     Yes          2      Graduate            No
# 115  LP001401    Male     Yes          1      Graduate            No
# 119  LP001422  Female      No          0      Graduate            No
# 126  LP001448     NaN     Yes         3+      Graduate            No
# 128  LP001451    Male     Yes          1      Graduate           Yes
# 130  LP001469    Male      No          0      Graduate           Yes
# 138  LP001492    Male      No          0      Graduate            No
# ...

# %%
df = pd.read_csv("./data_vis/Dataset_Boxplot_Train.csv")
 # Calculate IQR and detect outliers
Q1 = df['LoanAmount'].quantile(0.25)
Q3 = df['LoanAmount'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound)
print(upper_bound)

outliers = df[(df['LoanAmount'] < lower_bound) | (df['LoanAmount'] > upper_bound)]

print("Outliers in 'LoanAmount' column:")
print(outliers)

#  Box plot
plt.boxplot(df['LoanAmount'].dropna(), vert=True, whis=[5,95], showfliers=True)
plt.title("Box Plot of LoanAmount")
plt.ylabel("LoanAmount")
plt.show()
# Out:
# -2.0
# 270.0
# Outliers in 'LoanAmount' column:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 9    LP001020    Male     Yes          1      Graduate            No
# 21   LP001046    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 67   LP001233    Male     Yes          1      Graduate            No
# 126  LP001448     NaN     Yes         3+      Graduate            No
# 130  LP001469    Male      No          0      Graduate           Yes
# 135  LP001488    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 161  LP001562    Male     Yes          0      Graduate            No
# 171  LP001585     NaN     Yes         3+      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# ...

# %%
df = pd.read_csv("./data_vis/Dataset_Boxplot_Train.csv")
 # Calculate IQR and detect outliers
Q1 = df['Credit_History'].quantile(0.25)
Q3 = df['Credit_History'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound)
print(upper_bound)

outliers = df[(df['Credit_History'] < lower_bound) | (df['Credit_History'] > upper_bound)]

print("Outliers in 'Credit_History' column:")
print(outliers)

#  Box plot
plt.boxplot(df['Credit_History'].dropna(), vert=True, whis=[5,95], showfliers=True)
plt.title("Box Plot of Credit_History")
plt.ylabel("Credit_History")
plt.show()
# Out:
# 1.0
# 1.0
# Outliers in 'Credit_History' column:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 7    LP001014    Male     Yes         3+      Graduate            No
# 17   LP001036  Female      No          0      Graduate            No
# 20   LP001043    Male     Yes          0  Not Graduate            No
# 22   LP001047    Male     Yes          0  Not Graduate            No
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 576  LP002872     NaN     Yes          0      Graduate            No
# 584  LP002911    Male     Yes          1      Graduate            No
# 589  LP002926    Male     Yes          2      Graduate           Yes
# 597  LP002943    Male      No        NaN      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df = pd.read_csv("./data_vis/Dataset_Boxplot_Train.csv")
# Calculate IQR and detect outliers
Q1 = df['Loan_Amount_Term'].quantile(0.25)
Q3 = df['Loan_Amount_Term'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound)
print(upper_bound)

outliers = df[(df['Loan_Amount_Term'] < lower_bound) | (df['Loan_Amount_Term'] > upper_bound)]

print("Outliers in 'Loan_Amount_Term' column:")
print(outliers)

#  Box plot
plt.boxplot(df['Loan_Amount_Term'].dropna(), vert=True, showfliers=True)
plt.title("Box Plot of Loan_Amount_Term")
plt.ylabel("Loan_Amount_Term")
plt.show()
# Out:
# 360.0
# 360.0
# Outliers in 'Loan_Amount_Term' column:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 14   LP001030    Male     Yes          2      Graduate            No
# 16   LP001034    Male      No          1  Not Graduate            No
# 62   LP001207    Male     Yes          0  Not Graduate           Yes
# 66   LP001228    Male      No          0  Not Graduate            No
# 68   LP001238    Male     Yes         3+  Not Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 591  LP002931    Male     Yes          2      Graduate           Yes
# 593  LP002936    Male     Yes          0      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
